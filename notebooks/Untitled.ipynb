# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
df = pd.DataFrame({'Rainy':[29,28,32,35,36,12,18,30,45,55, 32,32,32,32,32], 'City':['City_A']*5 + ['City_B']*5 + ['City_C']*5})

# %%
sns.lineplot(y='Rainy', x='City', data=df)

# %%
import numpy as np
import seaborn as sns

a = np.random.normal(60, 10, 100000)
sns.distplot(a, hist=True, kde=True, bins=40)

b = np.random.normal(60, 20, 100000)
sns.distplot(b, hist=True, kde=True, bins=40)

# %%
from scipy import stats

# %%
stats.norm.cdf(70, loc=60, scale=10)
# Out:
# 0.8413447460685429

# %%
stats.norm.cdf(50, loc=60, scale=10)
# Out:
# 0.15865525393145707

# %%
stats.norm.cdf(70, loc=60, scale=10) - stats.norm.cdf(50, loc=60, scale=10)
# Out:
# 0.6826894921370859

# %%
stats.norm.cdf(80, loc=60, scale=20) - stats.norm.cdf(40, loc=60, scale=20)
# Out:
# 0.6826894921370859

# %%
def grab_cdf(a, r):
    return np.sum(a <= r)

# %%
cdf_a = [grab_cdf(a, r) / len(a) for r in range(ix(a)))]

# %%
plt.plot(range(int(np.min(a)), int(np.max(a))), cdf_a)

# %% [markdown]
# Z Distribution

# %%
c = (a - 60) / 10

# %%
sns.distplot(c, hist=True, kde=True, bins=40)

# %%
cdf_a
# Out:
# [0.0,
#  1e-05,
#  1e-05,
#  3e-05,
#  3e-05,
#  3e-05,
#  7e-05,
#  0.0001,
#  0.00015,
#  0.0002,
#  0.00025,
#  0.00037,
#  0.0005,
#  0.00072,
#  0.00099,
#  0.00137,
#  0.00183,
#  0.00244,
#  0.00339,
#  0.00456,
#  0.00617,
#  0.00828,
#  0.01073,
#  0.01357,
#  0.01757,
#  0.02247,
#  0.02811,
#  0.03528,
#  0.04384,
#  0.05366,
#  0.06564,
#  0.07998,
#  0.09603,
#  0.11429,
#  0.13462,
#  0.15788,
#  0.18369,
#  0.21126,
#  0.24225,
#  0.27404,
#  0.30841,
#  0.3441,
#  0.38105,
#  0.41902,
#  0.45892,
#  0.49908,
#  0.53977,
#  0.57985,
#  0.61845,
#  0.65591,
#  0.69109,
#  0.72524,
#  0.75805,
#  0.78859,
#  0.81563,
#  0.8412,
#  0.86385,
#  0.88424,
#  0.90207,
#  0.91845,
#  0.93247,
#  0.94489,
#  0.95551,
#  0.96432,
#  0.97174,
#  0.97751,
#  0.98208,
#  0.9861,
#  0.989,
#  0.99182,
#  0.99384,
#  0.99542,
#  0.99662,
#  0.99747,
#  0.99804,
#  0.99856,
#  0.99892,
#  0.99923,
#  0.9995,
#  0.99963,
#  0.99973,
#  0.99977,
#  0.99984,
#  0.99991,
#  0.99994,
# ...

# %%
range(int(np.min(a)), int(np.max(a)))
# Out:
# range(15, 104)

# %%
len(a)
# Out:
# 100000

# %%
cdf_a = [grab_cdf(a, r) / len(a) for r in a]

# %%
plt.plot(range(int(np.min(a)), int(np.max(a))), cdf_a)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-81-a942b073f1c9> in <module>
# ----> 1 plt.plot(range(int(np.min(a)), int(np.max(a))), cdf_a)
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2811     return gca().plot(
#    2812         *args, scalex=scalex, scaley=scaley, **({"data": data} if data
# -> 2813         is not None else {}), **kwargs)
#    2814
#    2815
#
# /anaconda3/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1808                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1809                         RuntimeWarning, stacklevel=2)
# -> 1810             return func(ax, *args, **kwargs)
#    1811
#    1812         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# ...
